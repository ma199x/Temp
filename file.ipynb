# %%
#read all data in file
f=open("r.txt","r")
print(f.read())
f.close()

# %%
f=open("w.txt","w")
f.write("1111\n222\n33")
f.close()

# %%
f=open("a.txt","a")
f.write("yudjjdkdjsxxjn dl;lfk")
f.close()
